# %% [markdown]
# ### Descrption : This notebook includes EDA(Exploratory data analysis) of train and test datasets of Berkley deep drive dataset.

# %% [markdown]
# #### Author : Riya Chougule

# %% [markdown]
# #### Date : 4/11/2020

# %%
import numpy as np
import pandas as pd
from PIL import Image
import seaborn as sns

# %% [markdown]
# #### Note : data1 is the variable regarding train dataset

# %%
data1=pd.read_csv("C:\\Users\\Admin\\Desktop\\Project_datasets\\bdd100k\\bdd100k\\images\\100k\\train\\trainA\\Train_100k.csv")

# %%
image1_train=Image.open("signal_view_trainA.jpg")
image1_train
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720 at 0x1B53354E2C8>

# %%
image2_train=Image.open("traffic_sign_boards_trainA.jpg")
image2_train
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720 at 0x1B5325659C8>

# %% [markdown]
# #### Note : data2 is the variable regarding test dataset

# %%
data2=pd.read_csv("C:\\Users\\Admin\\Desktop\\Project_datasets\\bdd100k\\bdd100k\\images\\100k\\test\\testA\\Test_100k.csv")

# %%
image3_test=Image.open("snowfall_testA.jpg")
image3_test
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720 at 0x1B53256D288>

# %%
image4_test=Image.open("tunnel_view_testA.jpg")
image4_test
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720 at 0x1B53256DA08>

# %%
data1.head()
# Out:
#      Name of the file File type Category  Size of file in kb  \
# 0      Label1 (1).jpg       jpg  Train A                  75
# 1    Label1 (100).jpg       jpg  Train A                  76
# 2   Label1 (1000).jpg       jpg  Train A                  83
# 3  Label1 (10000).jpg       jpg  Train A                  89
# 4  Label1 (10001).jpg       jpg  Train A                  73
#
#   No. of channels present
# 0                  3(RGB)
# 1                  3(RGB)
# 2                  3(RGB)
# 3                  3(RGB)
# 4                  3(RGB)

# %%
data2.head()
# Out:
#          Name of the file File type Category  Size of file in kb  \
# 0     label_testA (1).jpg       jpg   Test A                  95
# 1    label_testA (10).jpg       jpg   Test A                  64
# 2   label_testA (100).jpg       jpg   Test A                  54
# 3  label_testA (1000).jpg       jpg   Test A                  62
# 4  label_testA (1001).jpg       jpg   Test A                  72
#
#   No. of channels present
# 0                  3(RGB)
# 1                  3(RGB)
# 2                  3(RGB)
# 3                  3(RGB)
# 4                  3(RGB)

# %%
data1.shape
# Out:
# (61966, 5)

# %%
data2.shape
# Out:
# (1970, 5)

# %%
data1.tail()
# Out:
#        Name of the file File type Category  Size of file in kb  \
# 61961  Image (9995).jpg       jpg  Train B                  32
# 61962  Image (9996).jpg       jpg  Train B                  39
# 61963  Image (9997).jpg       jpg  Train B                  55
# 61964  Image (9998).jpg       jpg  Train B                  33
# 61965  Image (9999).jpg       jpg  Train B                  34
#
#       No. of channels present
# 61961                  3(RGB)
# 61962                  3(RGB)
# 61963                  3(RGB)
# 61964                  3(RGB)
# 61965                  3(RGB)

# %%
data2.tail()
# Out:
#           Name of the file File type Category  Size of file in kb  \
# 1965  Image_testB (95).jpg       jpg   Test B                  34
# 1966  Image_testB (96).jpg       jpg   Test B                  33
# 1967  Image_testB (97).jpg       jpg   Test B                  23
# 1968  Image_testB (98).jpg       jpg   Test B                  39
# 1969  Image_testB (99).jpg       jpg   Test B                  31
#
#      No. of channels present
# 1965                  3(RGB)
# 1966                  3(RGB)
# 1967                  3(RGB)
# 1968                  3(RGB)
# 1969                  3(RGB)

# %%
data1.columns
# Out:
# Index(['Name of the file', 'File type', 'Category', 'Size of file in kb',
#        'No. of channels present'],
#       dtype='object')

# %%
data2.columns
# Out:
# Index(['Name of the file', 'File type', 'Category', 'Size of file in kb',
#        'No. of channels present'],
#       dtype='object')

# %%
data1.describe()
# Out:
#        Size of file in kb
# count        61966.000000
# mean            57.542055
# std             19.358085
# min             16.000000
# 25%             41.000000
# 50%             57.000000
# 75%             72.000000
# max            150.000000

# %%
data2.describe()
# Out:
#        Size of file in kb
# count         1970.000000
# mean            56.820812
# std             19.028349
# min             20.000000
# 25%             41.000000
# 50%             56.000000
# 75%             71.000000
# max            125.000000

# %%
data1.nunique()
# Out:
# Name of the file           61966
# File type                      1
# Category                       2
# Size of file in kb           127
# No. of channels present        1
# dtype: int64

# %%
data2.nunique()
# Out:
# Name of the file           1970
# File type                     1
# Category                      2
# Size of file in kb           89
# No. of channels present       1
# dtype: int64
