# %% [markdown]
# ### Descrption : This notebook includes EDA(Exploratory data analysis) of train and test datasets of Berkley deep drive dataset

# %% [markdown]
# ### Date : 4/11/2020

# %% [markdown]
# ### Author : Riya Chougule

# %%
import pandas as pd
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Note : Here, I have used the variable data1 for train dataset, and data2 for test dataset.

# %%
data1=pd.read_csv("C:\\Users\\Admin\\Desktop\\Project_datasets\\bdd100k\\bdd100k\\images\\100k\\train\\trainA\\Train_100k.csv")

# %%
data2=pd.read_csv("C:\\Users\\Admin\\Desktop\\Project_datasets\\bdd100k\\bdd100k\\images\\100k\\test\\testA\\Test_100k.csv")

# %%
data1.head()
# Out:
#     Name_of_the _file File _ype Category  Size_of_file_in_kb  \
# 0      Label1 (1).jpg       jpg  Train A                  75
# 1    Label1 (100).jpg       jpg  Train A                  76
# 2   Label1 (1000).jpg       jpg  Train A                  83
# 3  Label1 (10000).jpg       jpg  Train A                  89
# 4  Label1 (10001).jpg       jpg  Train A                  73
#
#   No_of_channels_present
# 0                 3(RGB)
# 1                 3(RGB)
# 2                 3(RGB)
# 3                 3(RGB)
# 4                 3(RGB)

# %%
data2.head()
# Out:
#         Name_of_the _file File _ype Category  Size_of_file_in_kb  \
# 0     label_testA (1).jpg       jpg   Test A                  95
# 1    label_testA (10).jpg       jpg   Test A                  64
# 2   label_testA (100).jpg       jpg   Test A                  54
# 3  label_testA (1000).jpg       jpg   Test A                  62
# 4  label_testA (1001).jpg       jpg   Test A                  72
#
#   No_of_channels_present
# 0                 3(RGB)
# 1                 3(RGB)
# 2                 3(RGB)
# 3                 3(RGB)
# 4                 3(RGB)

# %%
data1.shape
# Out:
# (61966, 5)

# %%
data2.shape
# Out:
# (1970, 5)

# %%
image1_train=Image.open("signal_view_trainA.jpg")
image1_train
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720 at 0x19451484608>

# %%
image3_test=Image.open("snowfall_testA.jpg")
image3_test
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720 at 0x19451505F48>

# %%
data1.describe()
# Out:
#        Size_of_file_in_kb
# count        61966.000000
# mean            57.542055
# std             19.358085
# min             16.000000
# 25%             41.000000
# 50%             57.000000
# 75%             72.000000
# max            150.000000

# %%
data2.describe()
# Out:
#        Size_of_file_in_kb
# count         1970.000000
# mean            56.820812
# std             19.028349
# min             20.000000
# 25%             41.000000
# 50%             56.000000
# 75%             71.000000
# max            125.000000

# %%
data1.boxplot()

# %%
data2.boxplot()

# %%
data1.Size_of_file_in_kb.hist()

# %%
data2.Size_of_file_in_kb.hist()

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61966 entries, 0 to 61965
# Data columns (total 5 columns):
# Name_of_the _file         61966 non-null object
# File _ype                 61966 non-null object
# Category                  61966 non-null object
# Size_of_file_in_kb        61966 non-null int64
# No_of_channels_present    61966 non-null object
# dtypes: int64(1), object(4)
# memory usage: 2.4+ MB

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1970 entries, 0 to 1969
# Data columns (total 5 columns):
# Name_of_the _file         1970 non-null object
# File _ype                 1970 non-null object
# Category                  1970 non-null object
# Size_of_file_in_kb        1970 non-null int64
# No_of_channels_present    1970 non-null object
# dtypes: int64(1), object(4)
# memory usage: 77.1+ KB

# %%
data1.isnull()
# Out:
#        Name_of_the _file  File _ype  Category  Size_of_file_in_kb  \
# 0                  False      False     False               False
# 1                  False      False     False               False
# 2                  False      False     False               False
# 3                  False      False     False               False
# 4                  False      False     False               False
# ...                  ...        ...       ...                 ...
# 61961              False      False     False               False
# 61962              False      False     False               False
# 61963              False      False     False               False
# 61964              False      False     False               False
# 61965              False      False     False               False
#
#        No_of_channels_present
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# ...

# %%
data2.isnull()
# Out:
#       Name_of_the _file  File _ype  Category  Size_of_file_in_kb  \
# 0                 False      False     False               False
# 1                 False      False     False               False
# 2                 False      False     False               False
# 3                 False      False     False               False
# 4                 False      False     False               False
# ...                 ...        ...       ...                 ...
# 1965              False      False     False               False
# 1966              False      False     False               False
# 1967              False      False     False               False
# 1968              False      False     False               False
# 1969              False      False     False               False
#
#       No_of_channels_present
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                      False
# ...

# %%
data1[data1.Size_of_file_in_kb > 100]
# Out:
#         Name_of_the _file File _ype Category  Size_of_file_in_kb  \
# 100    Label1 (10089).jpg       jpg  Train A                 103
# 103    Label1 (10091).jpg       jpg  Train A                 150
# 167    Label1 (10149).jpg       jpg  Train A                 107
# 178    Label1 (10159).jpg       jpg  Train A                 103
# 200    Label1 (10179).jpg       jpg  Train A                 106
# ...                   ...       ...      ...                 ...
# 37014   Label1 (9817).jpg       jpg  Train A                 103
# 37039    Label1 (984).jpg       jpg  Train A                 102
# 37126   Label1 (9918).jpg       jpg  Train A                 102
# 37185   Label1 (9971).jpg       jpg  Train A                 104
# 47612   Image (19355).jpg       jpg  Train B                 104
#
#       No_of_channels_present
# 100                   3(RGB)
# 103                   3(RGB)
# 167                   3(RGB)
# 178                   3(RGB)
# 200                   3(RGB)
# ...

# %%
img1 = cv2.imread('Img1.jpg')
img2=cv2.imread("Img_seg1.png")
NUM_ROWS = 1
IMGs_IN_ROW = 2
f, ax = plt.subplots(NUM_ROWS, IMGs_IN_ROW, figsize=(16,6))

ax[0].imshow(img1)
ax[1].imshow(img2)

#ax[0].set_title('Original image')
#ax[1].set_title('Segmented image')

# %%
img3 = cv2.imread('Img2.jpg')
img4=cv2.imread("Img_seg2.png")
NUM_ROWS = 1
IMGs_IN_ROW = 2
f, ax = plt.subplots(NUM_ROWS, IMGs_IN_ROW, figsize=(16,6))

ax[0].imshow(img3)
ax[1].imshow(img4)

ax[0].set_title('Original image')
ax[1].set_title('Segmented image')
# Out:
# Text(0.5, 1.0, 'Segmented image')
